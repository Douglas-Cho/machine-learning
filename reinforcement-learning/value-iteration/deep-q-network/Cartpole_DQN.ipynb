# %%
import sys
import gym
import pylab
import random
import numpy as np
from collections import deque
from keras.layers import Dense
from keras.optimizers import Adam
from keras.models import Sequential

EPISODES = 500


# DQN Agent for the Cartpole
# it uses Neural Network to approximate q function
# and replay memory & target q network
class DQNAgent:
    def __init__(self, state_size, action_size):
        # if you want to see Cartpole learning, then change to True
        self.render = True
        self.load_model = False

        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size

        # These are hyper parameters for the DQN
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.train_start = 1000
        # create replay memory using deque
        self.memory = deque(maxlen=2000)

        # create main model and target model
        self.model = self.build_model()
        self.target_model = self.build_model()

        # initialize target model
        self.update_target_model()

        if self.load_model:
            self.model.load_weights("./save_model/cartpole_dqn.h5")

    # approximate Q function using Neural Network
    # state is input and Q Value of each action is output of network
    def build_model(self):
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(24, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(self.action_size, activation='linear',
                        kernel_initializer='he_uniform'))
        model.summary()
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model

    # after some time interval update the target model to be same with model
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # get action from model using epsilon-greedy policy
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model.predict(state)
            return np.argmax(q_value[0])

    # save sample <s,a,r,s'> to the replay memory
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    # pick samples randomly from replay memory (with batch_size)
    def train_model(self):
        if len(self.memory) < self.train_start:
            return
        batch_size = min(self.batch_size, len(self.memory))
        mini_batch = random.sample(self.memory, batch_size)

        update_input = np.zeros((batch_size, self.state_size))
        update_target = np.zeros((batch_size, self.state_size))
        action, reward, done = [], [], []

        for i in range(self.batch_size):
            update_input[i] = mini_batch[i][0]
            action.append(mini_batch[i][1])
            reward.append(mini_batch[i][2])
            update_target[i] = mini_batch[i][3]
            done.append(mini_batch[i][4])

        target = self.model.predict(update_input)
        target_val = self.target_model.predict(update_target)

        for i in range(self.batch_size):
            # Q Learning: get maximum Q value at s' from target model
            if done[i]:
                target[i][action[i]] = reward[i]
            else:
                target[i][action[i]] = reward[i] + self.discount_factor * (
                    np.amax(target_val[i]))

        # and do the model fit!
        self.model.fit(update_input, target, batch_size=self.batch_size,
                       epochs=1, verbose=0)


if __name__ == "__main__":
    # In case of CartPole-v1, maximum length of episode is 500
    env = gym.make('CartPole-v1')
    # get size of state and action from environment
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    agent = DQNAgent(state_size, action_size)

    scores, episodes = [], []

    for e in range(EPISODES):
        done = False
        score = 0
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            # get action for the current state and go one step in environment
            action = agent.get_action(state)
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])
            # if an action make the episode end, then gives penalty of -100
            reward = reward if not done or score == 499 else -100

            # save the sample <s, a, r, s'> to the replay memory
            agent.append_sample(state, action, reward, next_state, done)
            # every time step do the training
            agent.train_model()
            score += reward
            state = next_state

            if done:
                # every episode update the target model to be same with model
                agent.update_target_model()

                # every episode, plot the play time
                score = score if score == 500 else score + 100
                scores.append(score)
                episodes.append(e)
                pylab.plot(episodes, scores, 'b')
                pylab.savefig("./save_graph/cartpole_dqn.png")
                print("episode:", e, "  score:", score, "  memory length:",
                      len(agent.memory), "  epsilon:", agent.epsilon)

                # if the mean of scores of last 10 episode is bigger than 490
                # stop training
            if np.mean(scores[-min(10, len(scores)):]) > 490:
                    env.close()
                    break
                    #sys.exit()

        # save the model
        if e % 50 == 0:
            agent.model.save_weights("./save_model/cartpole_dqn.h5")
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# C:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode: 0   score: 13.0   memory length: 14   epsilon: 0.986090636999001
# episode: 1   score: 9.0   memory length: 24   epsilon: 0.9762739865836303
# episode: 2   score: 10.0   memory length: 35   epsilon: 0.9655885070369844
# episode: 3   score: 12.0   memory length: 48   epsilon: 0.9531108968798944
# episode: 4   score: 20.0   memory length: 69   epsilon: 0.933294459381294
# episode: 5   score: 27.0   memory length: 97   epsilon: 0.9075119613694457
# episode: 6   score: 13.0   memory length: 111   epsilon: 0.8948890480710096
# episode: 7   score: 44.0   memory length: 156   epsilon: 0.8554924148377159
# episode: 8   score: 16.0   memory length: 173   epsilon: 0.8410648110498392
# episode: 9   score: 14.0   memory length: 188   epsilon: 0.8285367691502946
# episode: 10   score: 18.0   memory length: 207   epsilon: 0.812935450673631
# episode: 11   score: 17.0   memory length: 225   epsilon: 0.7984263308107633
# episode: 12   score: 20.0   memory length: 246   epsilon: 0.7818259902485653
# episode: 13   score: 39.0   memory length: 286   epsilon: 0.7511551214098489
# episode: 14   score: 12.0   memory length: 299   epsilon: 0.7414484806367364
# episode: 15   score: 29.0   memory length: 329   epsilon: 0.7195245662400531
# episode: 16   score: 11.0   memory length: 341   epsilon: 0.7109376021267352
# episode: 17   score: 12.0   memory length: 354   epsilon: 0.7017506636113059
# episode: 18   score: 10.0   memory length: 365   epsilon: 0.6940698870404746
# episode: 19   score: 45.0   memory length: 411   epsilon: 0.662850610905674
# episode: 20   score: 10.0   memory length: 422   epsilon: 0.6555956018173954
# episode: 21   score: 19.0   memory length: 442   epsilon: 0.6426075087326283
# episode: 22   score: 24.0   memory length: 467   epsilon: 0.6267336333646188
# episode: 23   score: 17.0   memory length: 485   epsilon: 0.6155478087077623
# episode: 24   score: 8.0   memory length: 494   epsilon: 0.6100299865219717
# episode: 25   score: 14.0   memory length: 509   epsilon: 0.6009433131399452
# episode: 26   score: 43.0   memory length: 553   epsilon: 0.5750624217730242
# episode: 27   score: 14.0   memory length: 568   epsilon: 0.5664966061305491
# episode: 28   score: 14.0   memory length: 583   epsilon: 0.5580583821978482
# episode: 29   score: 40.0   memory length: 624   epsilon: 0.5356297035976458
# episode: 30   score: 20.0   memory length: 645   epsilon: 0.5244932528672183
# episode: 31   score: 8.0   memory length: 654   epsilon: 0.5197916513571034
# episode: 32   score: 11.0   memory length: 666   epsilon: 0.5135883436925301
# episode: 33   score: 11.0   memory length: 678   epsilon: 0.5074590676632879
# episode: 34   score: 11.0   memory length: 690   epsilon: 0.5014029397595902
# episode: 35   score: 10.0   memory length: 701   epsilon: 0.4959150020176678
# episode: 36   score: 12.0   memory length: 714   epsilon: 0.4895066468838467
# episode: 37   score: 11.0   memory length: 726   epsilon: 0.4836647671103911
# episode: 38   score: 35.0   memory length: 762   epsilon: 0.4665541192401326
# episode: 39   score: 11.0   memory length: 774   epsilon: 0.46098615996978987
# episode: 40   score: 9.0   memory length: 784   epsilon: 0.4563969875256424
# episode: 41   score: 7.0   memory length: 792   epsilon: 0.452758565214779
# episode: 42   score: 11.0   memory length: 804   epsilon: 0.44735524511437874
# episode: 43   score: 15.0   memory length: 820   epsilon: 0.4402509941152613
# episode: 44   score: 8.0   memory length: 829   epsilon: 0.4363045472783448
# episode: 45   score: 10.0   memory length: 840   epsilon: 0.43152912216191214
# episode: 46   score: 14.0   memory length: 855   epsilon: 0.4251013001293033
# episode: 47   score: 48.0   memory length: 904   epsilon: 0.4047635127496183
# episode: 48   score: 41.0   memory length: 946   epsilon: 0.3881073448764583
# episode: 49   score: 34.0   memory length: 981   epsilon: 0.3747519917093475
# episode: 50   score: 12.0   memory length: 994   epsilon: 0.36990933956087574
# episode: 51   score: 9.0   memory length: 1004   epsilon: 0.3662268477740143
# episode: 52   score: 9.0   memory length: 1014   epsilon: 0.36258101563401773
# episode: 53   score: 30.0   memory length: 1045   epsilon: 0.35150798586723914
# episode: 54   score: 20.0   memory length: 1066   epsilon: 0.3441996694320795
# episode: 55   score: 15.0   memory length: 1082   epsilon: 0.3387335865546259
# episode: 56   score: 15.0   memory length: 1098   epsilon: 0.33335430812434824
# episode: 57   score: 11.0   memory length: 1110   epsilon: 0.3293759846379912
# episode: 58   score: 16.0   memory length: 1127   epsilon: 0.32382116483926726
# episode: 59   score: 25.0   memory length: 1153   epsilon: 0.3155062193168902
# episode: 60   score: 14.0   memory length: 1168   epsilon: 0.3108066110545554
# episode: 61   score: 12.0   memory length: 1181   epsilon: 0.30679027935764497
# episode: 62   score: 12.0   memory length: 1194   epsilon: 0.30282584784472627
# episode: 63   score: 15.0   memory length: 1210   epsilon: 0.29801680434829997
# episode: 64   score: 13.0   memory length: 1224   epsilon: 0.2938715804362218
# episode: 65   score: 32.0   memory length: 1257   epsilon: 0.284327391068757
# episode: 66   score: 33.0   memory length: 1291   epsilon: 0.27481807913093287
# episode: 67   score: 61.0   memory length: 1353   epsilon: 0.2582887971370021
# episode: 68   score: 49.0   memory length: 1403   epsilon: 0.24568575753695765
# episode: 69   score: 68.0   memory length: 1472   epsilon: 0.22929715625813843
# episode: 70   score: 59.0   memory length: 1532   epsilon: 0.21593744687294092
# episode: 71   score: 49.0   memory length: 1582   epsilon: 0.20540091480403888
# episode: 72   score: 68.0   memory length: 1651   epsilon: 0.1916995357384587
# episode: 73   score: 270.0   memory length: 1922   epsilon: 0.1461734072526738
# episode: 74   score: 161.0   memory length: 2000   epsilon: 0.12430181296320032
# episode: 75   score: 298.0   memory length: 2000   epsilon: 0.09216339036195662
# episode: 76   score: 366.0   memory length: 2000   epsilon: 0.06383996223774882
# episode: 77   score: 299.0   memory length: 2000   epsilon: 0.047286708962080405
# episode: 78   score: 442.0   memory length: 2000   epsilon: 0.030356407448045058
# episode: 79   score: 360.0   memory length: 2000   epsilon: 0.02115395727838379
# episode: 80   score: 178.0   memory length: 2000   epsilon: 0.01768536450897841
# episode: 81   score: 500.0   memory length: 2000   epsilon: 0.01072403267043979
# episode: 82   score: 495.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 83   score: 178.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 84   score: 281.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 85   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 86   score: 321.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 87   score: 400.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 88   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 89   score: 424.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 90   score: 228.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 91   score: 206.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 92   score: 472.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 93   score: 211.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 94   score: 206.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 95   score: 194.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 96   score: 161.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 97   score: 199.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 98   score: 174.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 99   score: 205.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 100   score: 160.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 101   score: 166.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 102   score: 174.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 103   score: 152.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 104   score: 205.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 105   score: 187.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 106   score: 229.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 107   score: 210.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 108   score: 243.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 109   score: 207.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 110   score: 199.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 111   score: 247.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 112   score: 283.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 113   score: 311.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 114   score: 315.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 115   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 116   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 117   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 118   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 119   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 120   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 121   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 122   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 123   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 124   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896

# %%
env.close()
