# %%
import sys
import gym
import pylab
import random
import numpy as np
from collections import deque
from keras.layers import Dense, LSTM
from keras.optimizers import Adam
from keras.models import Sequential

EPISODES = 500


# DRQN Agent for the Cartpole
# it uses Neural Network to approximate q function
# and replay memory & target q network
class DRQNAgent:
    def __init__(self, state_size, action_size):
        # if you want to see Cartpole learning, then change to True
        self.render = False
        self.load_model = False

        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size

        # These are hyper parameters for the DRQN
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.train_start = 1000
        
        # create replay memory using deque
        self.memory = deque(maxlen=2000)

        # create main model and target model
        self.model = self.build_model()
        self.target_model = self.build_model()

        # initialize target model
        self.update_target_model()

        if self.load_model:
            self.model.load_weights("./save_model/cartpole_drqn.h5")

    # approximate Q function using Neural Network
    # state is input and Q Value of each action is output of network
    def build_model(self):
        model = Sequential()
        model.add(LSTM(32, input_shape=(self.state_size, 2), kernel_initializer='orthogonal', recurrent_initializer='zeros'))
        model.add(Dense(self.action_size))
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model

    # after some time interval update the target model to be same with model
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # get action from model using epsilon-greedy policy
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model.predict(state)
            return np.argmax(q_value[0])

    # save sample <s,a,r,s'> to the replay memory
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    # pick samples randomly from replay memory (with batch_size)
    def train_model(self):
        if len(self.memory) < self.train_start:
            return
        batch_size = min(self.batch_size, len(self.memory))
        mini_batch = random.sample(self.memory, batch_size)

        update_input = np.zeros((batch_size, self.state_size, 2))
        update_target = np.zeros((batch_size, self.state_size, 2))
        action, reward, done = [], [], []

        for i in range(self.batch_size):
            update_input[i] = mini_batch[i][0]
            action.append(mini_batch[i][1])
            reward.append(mini_batch[i][2])
            update_target[i] = mini_batch[i][3]
            done.append(mini_batch[i][4])

        target = self.model.predict(update_input)
        target_val = self.target_model.predict(update_target)

        for i in range(self.batch_size):
            # Q Learning: get maximum Q value at s' from target model
            if done[i]:
                target[i][action[i]] = reward[i]
            else:
                target[i][action[i]] = reward[i] + self.discount_factor * (
                    np.amax(target_val[i]))

        # and do the model fit!      
        self.model.fit(update_input, target, batch_size=self.batch_size,
                       epochs=1, verbose=0)


if __name__ == "__main__":
    # In case of CartPole-v1, maximum length of episode is 500
    env = gym.make('CartPole-v1')
    
    # Total number of states to use
    number_of_states = 8
    
    # get size of state and action from environment
    state_size = env.observation_space.shape[0]
    expanded_state_size = state_size * number_of_states
    action_size = env.action_space.n

    agent = DRQNAgent(expanded_state_size, action_size)

    scores, episodes = [], []

    for e in range(EPISODES):
        done = False
        score = 0
        state = env.reset()
        
        # expand the state with past states and initialize
        expanded_state = np.zeros(expanded_state_size)
        expanded_next_state = np.zeros(expanded_state_size)
        for h in range(state_size):
            expanded_state[(h + 1) * number_of_states -1] = state[h]
 
        # reshape states for LSTM input without embedding layer
        reshaped_state = np.zeros((1, expanded_state_size, 2))
        for i in range(expanded_state_size):
            for j in range(2):
                reshaped_state[0, i, j] = expanded_state[i]

        while not done:
            if agent.render:
                env.render()

            # get action for the current state and go one step in environment
            action = agent.get_action(reshaped_state)
            next_state, reward, done, info = env.step(action)
            
            # update the expanded next state with next state values
            for h in range(state_size):
                expanded_next_state[(h + 1) * number_of_states -1] = next_state[h]
            
            # reshape expanded next state for LSTM input without embedding layer
            reshaped_next_state = np.zeros((1, expanded_state_size, 2))
            for i in range(expanded_state_size):
                for j in range(2):
                    reshaped_next_state[0, i, j] = expanded_next_state[i]
                    
            # if an action make the episode end, then gives penalty of -100
            reward = reward if not done or score == 499 else -100

            # save the sample <s, a, r, s'> to the replay memory
            agent.append_sample(reshaped_state, action, reward, reshaped_next_state, done)
            
            # every time step do the training
            agent.train_model()
            score += reward
            reshaped_state = reshaped_next_state
            
            # Shifting past state elements to the left by one
            expanded_next_state = np.roll(expanded_next_state, -1)

            if done:
                # every episode update the target model to be same with model
                agent.update_target_model()

                # every episode, plot the play time
                score = score if score == 500 else score + 100
                scores.append(score)
                episodes.append(e)
                pylab.plot(episodes, scores, 'b')
                pylab.savefig("./save_graph/cartpole_drqn.png")
                print("episode:", e, "  score:", score, "  memory length:",
                      len(agent.memory), "  epsilon:", agent.epsilon)

            # if the mean of scores of last 10 episode is bigger than 490
            # stop training
            # revised to exit cleanly on Jupiter notebook
            if np.mean(scores[-min(10, len(scores)):]) > 490:
                #sys.exit()
                env.close()
                break

        # save the model
        if e % 50 == 0:
            agent.model.save_weights("./save_model/cartpole_drqn.h5")
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode: 0   score: 19.0   memory length: 20   epsilon: 0.9801888648295347
# episode: 1   score: 27.0   memory length: 48   epsilon: 0.9531108968798944
# episode: 2   score: 34.0   memory length: 83   epsilon: 0.9203129279589385
# episode: 3   score: 21.0   memory length: 105   epsilon: 0.9002772252562138
# episode: 4   score: 21.0   memory length: 127   epsilon: 0.8806777104745716
# episode: 5   score: 13.0   memory length: 141   epsilon: 0.8684280445126921
# episode: 6   score: 12.0   memory length: 154   epsilon: 0.857205969570888
# episode: 7   score: 19.0   memory length: 174   epsilon: 0.8402237462387894
# episode: 8   score: 12.0   memory length: 187   epsilon: 0.8293661352855802
# episode: 9   score: 13.0   memory length: 201   epsilon: 0.8178301806491574
# episode: 10   score: 9.0   memory length: 211   epsilon: 0.8096885832327116
# episode: 11   score: 8.0   memory length: 220   epsilon: 0.8024304668606914
# episode: 12   score: 11.0   memory length: 232   epsilon: 0.7928540855310416
# episode: 13   score: 28.0   memory length: 261   epsilon: 0.7701803374578359
# episode: 14   score: 32.0   memory length: 294   epsilon: 0.7451668707698216
# episode: 15   score: 9.0   memory length: 304   epsilon: 0.7377486453075807
# episode: 16   score: 23.0   memory length: 328   epsilon: 0.7202448110511043
# episode: 17   score: 28.0   memory length: 357   epsilon: 0.6996475161707122
# episode: 18   score: 16.0   memory length: 374   epsilon: 0.6878481863585387
# episode: 19   score: 14.0   memory length: 389   epsilon: 0.677602375588654
# episode: 20   score: 13.0   memory length: 403   epsilon: 0.6681773581762521
# episode: 21   score: 10.0   memory length: 414   epsilon: 0.660864046961939
# episode: 22   score: 12.0   memory length: 427   epsilon: 0.6523241732116479
# episode: 23   score: 16.0   memory length: 444   epsilon: 0.6413229363226717
# episode: 24   score: 17.0   memory length: 462   epsilon: 0.6298767245155701
# episode: 25   score: 14.0   memory length: 477   epsilon: 0.6204944249678943
# episode: 26   score: 11.0   memory length: 489   epsilon: 0.6130893082982078
# episode: 27   score: 13.0   memory length: 503   epsilon: 0.6045616265570569
# episode: 28   score: 11.0   memory length: 515   epsilon: 0.5973466554009469
# episode: 29   score: 16.0   memory length: 532   epsilon: 0.5872725966265356
# episode: 30   score: 13.0   memory length: 546   epsilon: 0.5791040088995179
# episode: 31   score: 13.0   memory length: 560   epsilon: 0.5710490410244006
# episode: 32   score: 7.0   memory length: 568   epsilon: 0.5664966061305491
# episode: 33   score: 11.0   memory length: 580   epsilon: 0.5597359112837013
# episode: 34   score: 8.0   memory length: 589   epsilon: 0.5547183916275941
# episode: 35   score: 12.0   memory length: 602   epsilon: 0.547550162317433
# episode: 36   score: 10.0   memory length: 613   epsilon: 0.5415571356255309
# episode: 37   score: 8.0   memory length: 622   epsilon: 0.5367025720391522
# episode: 38   score: 25.0   memory length: 648   epsilon: 0.522921346063882
# episode: 39   score: 11.0   memory length: 660   epsilon: 0.5166806879356919
# episode: 40   score: 12.0   memory length: 673   epsilon: 0.5100039926842729
# episode: 41   score: 9.0   memory length: 683   epsilon: 0.5049268418435943
# episode: 42   score: 9.0   memory length: 693   epsilon: 0.4999002346477277
# episode: 43   score: 15.0   memory length: 709   epsilon: 0.4919615398850291
# episode: 44   score: 7.0   memory length: 717   epsilon: 0.48803959497362914
# episode: 45   score: 8.0   memory length: 726   epsilon: 0.4836647671103911
# episode: 46   score: 7.0   memory length: 734   epsilon: 0.47980896453558947
# episode: 47   score: 9.0   memory length: 744   epsilon: 0.47503240881720094
# episode: 48   score: 18.0   memory length: 763   epsilon: 0.4660875651208925
# episode: 49   score: 8.0   memory length: 772   epsilon: 0.4619095170944617
# episode: 50   score: 9.0   memory length: 782   epsilon: 0.4573111525195289
# episode: 51   score: 7.0   memory length: 790   epsilon: 0.4536654424342049
# episode: 52   score: 17.0   memory length: 808   epsilon: 0.4455685064764183
# episode: 53   score: 9.0   memory length: 818   epsilon: 0.44113281861968207
# episode: 54   score: 20.0   memory length: 839   epsilon: 0.4319610832451573
# episode: 55   score: 7.0   memory length: 847   epsilon: 0.42851746532991924
# episode: 56   score: 12.0   memory length: 860   epsilon: 0.4229800403927701
# episode: 57   score: 10.0   memory length: 871   epsilon: 0.41835045419835276
# episode: 58   score: 15.0   memory length: 887   epsilon: 0.41170681546900234
# episode: 59   score: 10.0   memory length: 898   epsilon: 0.4072006165777428
# episode: 60   score: 11.0   memory length: 910   epsilon: 0.4023409950366106
# episode: 61   score: 10.0   memory length: 921   epsilon: 0.3979373065922575
# episode: 62   score: 11.0   memory length: 933   epsilon: 0.3931882354258422
# episode: 63   score: 24.0   memory length: 958   epsilon: 0.38347558663089293
# episode: 64   score: 11.0   memory length: 970   epsilon: 0.3788991048049279
# episode: 65   score: 12.0   memory length: 983   epsilon: 0.37400286247792053
# episode: 66   score: 7.0   memory length: 991   epsilon: 0.37102129074024554
# episode: 67   score: 11.0   memory length: 1003   epsilon: 0.3665934412152296
# episode: 68   score: 8.0   memory length: 1012   epsilon: 0.3633072668604718
# episode: 69   score: 39.0   memory length: 1052   epsilon: 0.3490547993433876
# episode: 70   score: 13.0   memory length: 1066   epsilon: 0.3441996694320795
# episode: 71   score: 14.0   memory length: 1081   epsilon: 0.3390726592138397
# episode: 72   score: 9.0   memory length: 1091   epsilon: 0.3356971502737668
# episode: 73   score: 8.0   memory length: 1100   epsilon: 0.33268793286240766
# episode: 74   score: 12.0   memory length: 1113   epsilon: 0.32838884448265515
# episode: 75   score: 12.0   memory length: 1126   epsilon: 0.32414531014941667
# episode: 76   score: 14.0   memory length: 1141   epsilon: 0.31931701871011153
# episode: 77   score: 8.0   memory length: 1150   epsilon: 0.31645463417195824
# episode: 78   score: 10.0   memory length: 1161   epsilon: 0.31299098609021553
# episode: 79   score: 12.0   memory length: 1174   epsilon: 0.308946427275922
# episode: 80   score: 20.0   memory length: 1195   epsilon: 0.3025230219968815
# episode: 81   score: 10.0   memory length: 1206   epsilon: 0.29921185770452
# episode: 82   score: 23.0   memory length: 1230   epsilon: 0.29211275315428575
# episode: 83   score: 10.0   memory length: 1241   epsilon: 0.28891553096867023
# episode: 84   score: 21.0   memory length: 1263   epsilon: 0.28262568595092585
# episode: 85   score: 16.0   memory length: 1280   epsilon: 0.27785929486848676
# episode: 86   score: 9.0   memory length: 1290   epsilon: 0.2750931723032361
# episode: 87   score: 15.0   memory length: 1306   epsilon: 0.2707245391743544
# episode: 88   score: 10.0   memory length: 1317   epsilon: 0.2677614145127563
# episode: 89   score: 12.0   memory length: 1330   epsilon: 0.2643013251257632
# episode: 90   score: 12.0   memory length: 1343   epsilon: 0.2608859480009449
# episode: 91   score: 13.0   memory length: 1357   epsilon: 0.25725719064833996
# episode: 92   score: 10.0   memory length: 1368   epsilon: 0.2544414683340336
# episode: 93   score: 8.0   memory length: 1377   epsilon: 0.2521606336708316
# episode: 94   score: 11.0   memory length: 1389   epsilon: 0.24915129331788444
# episode: 95   score: 12.0   memory length: 1402   epsilon: 0.24593168922618383
# episode: 96   score: 7.0   memory length: 1410   epsilon: 0.24397110804469957
# episode: 97   score: 14.0   memory length: 1425   epsilon: 0.24033704771580874
# episode: 98   score: 22.0   memory length: 1448   epsilon: 0.23486967737462733
# episode: 99   score: 10.0   memory length: 1459   epsilon: 0.23229899007966381
# episode: 100   score: 10.0   memory length: 1470   epsilon: 0.22975643938045995
# episode: 101   score: 8.0   memory length: 1479   epsilon: 0.22769688338723304
# episode: 102   score: 7.0   memory length: 1487   epsilon: 0.22588167109777058
# episode: 103   score: 8.0   memory length: 1496   epsilon: 0.2238568488524224
# episode: 104   score: 9.0   memory length: 1506   epsilon: 0.2216283271062282
# episode: 105   score: 9.0   memory length: 1516   epsilon: 0.21942199056097256
# episode: 106   score: 10.0   memory length: 1527   epsilon: 0.21702038074196223
# episode: 107   score: 11.0   memory length: 1539   epsilon: 0.21443041188095732
# episode: 108   score: 13.0   memory length: 1553   epsilon: 0.21144782144365132
# episode: 109   score: 10.0   memory length: 1564   epsilon: 0.20913349021874023
# episode: 110   score: 8.0   memory length: 1573   epsilon: 0.20725880007153075
# episode: 111   score: 9.0   memory length: 1583   epsilon: 0.20519551388923485
# episode: 112   score: 10.0   memory length: 1594   epsilon: 0.2029496152000772
# episode: 113   score: 9.0   memory length: 1604   epsilon: 0.20092922746937492
# episode: 114   score: 13.0   memory length: 1618   epsilon: 0.1981344299069931
# episode: 115   score: 9.0   memory length: 1628   epsilon: 0.19616197792269574
# episode: 116   score: 8.0   memory length: 1637   epsilon: 0.19440356549968224
# episode: 117   score: 9.0   memory length: 1647   epsilon: 0.19246825471748086
# episode: 118   score: 8.0   memory length: 1656   epsilon: 0.19074295313908668
# episode: 119   score: 7.0   memory length: 1664   epsilon: 0.18922233964839782
# episode: 120   score: 9.0   memory length: 1674   epsilon: 0.1873386085902063
# episode: 121   score: 9.0   memory length: 1684   epsilon: 0.18547363030035172
# episode: 122   score: 7.0   memory length: 1692   epsilon: 0.18399502414604677
# episode: 123   score: 11.0   memory length: 1704   epsilon: 0.1817991871399145
# episode: 124   score: 8.0   memory length: 1713   epsilon: 0.18016952397814437
# episode: 125   score: 10.0   memory length: 1724   epsilon: 0.17819753886960493
# episode: 126   score: 10.0   memory length: 1735   epsilon: 0.17624713746280615
# episode: 127   score: 7.0   memory length: 1743   epsilon: 0.1748420854254404
# episode: 128   score: 8.0   memory length: 1752   epsilon: 0.17327478630695967
# episode: 129   score: 7.0   memory length: 1760   epsilon: 0.1718934300192521
# episode: 130   score: 15.0   memory length: 1776   epsilon: 0.16916366640232217
# episode: 131   score: 7.0   memory length: 1784   epsilon: 0.16781508419242955
# episode: 132   score: 8.0   memory length: 1793   epsilon: 0.16631077570238512
# episode: 133   score: 11.0   memory length: 1805   epsilon: 0.16432598639897444
# episode: 134   score: 8.0   memory length: 1814   epsilon: 0.16285295447419557
# episode: 135   score: 9.0   memory length: 1824   epsilon: 0.16123173380420852
# episode: 136   score: 8.0   memory length: 1833   epsilon: 0.15978643901921685
# episode: 137   score: 7.0   memory length: 1841   epsilon: 0.15851261259049118
# episode: 138   score: 10.0   memory length: 1852   epsilon: 0.1567776659433432
# episode: 139   score: 10.0   memory length: 1863   epsilon: 0.15506170857294269
# episode: 140   score: 8.0   memory length: 1872   epsilon: 0.15367172241162955
# episode: 141   score: 9.0   memory length: 1882   epsilon: 0.15214190200664743
# episode: 142   score: 9.0   memory length: 1892   epsilon: 0.15062731114705447
# episode: 143   score: 8.0   memory length: 1901   epsilon: 0.14927707529619813
# episode: 144   score: 10.0   memory length: 1912   epsilon: 0.14764321312555637
# episode: 145   score: 8.0   memory length: 1921   epsilon: 0.14631972697965345
# episode: 146   score: 8.0   memory length: 1930   epsilon: 0.14500810467456865
# episode: 147   score: 9.0   memory length: 1940   epsilon: 0.1435645316219759
# episode: 148   score: 11.0   memory length: 1952   epsilon: 0.14185120098835316
# episode: 149   score: 7.0   memory length: 1960   epsilon: 0.14072035528032842
# episode: 150   score: 7.0   memory length: 1968   epsilon: 0.13959852473753628
# episode: 151   score: 10.0   memory length: 1979   epsilon: 0.1380705958965304
# episode: 152   score: 9.0   memory length: 1989   epsilon: 0.13669608657486898
# episode: 153   score: 9.0   memory length: 1999   epsilon: 0.13533526065815754
# episode: 154   score: 9.0   memory length: 2000   epsilon: 0.13398798192646064
# episode: 155   score: 10.0   memory length: 2000   epsilon: 0.13252146140041268
# episode: 156   score: 9.0   memory length: 2000   epsilon: 0.13120219437739233
# episode: 157   score: 9.0   memory length: 2000   epsilon: 0.1298960608156215
# episode: 158   score: 9.0   memory length: 2000   epsilon: 0.12860292996992018
# episode: 159   score: 8.0   memory length: 2000   epsilon: 0.12745012251921148
# episode: 160   score: 9.0   memory length: 2000   epsilon: 0.1261813412822505
# episode: 161   score: 8.0   memory length: 2000   epsilon: 0.1250502411556467
# episode: 162   score: 8.0   memory length: 2000   epsilon: 0.1239292803054478
# episode: 163   score: 8.0   memory length: 2000   epsilon: 0.12281836784232969
# episode: 164   score: 8.0   memory length: 2000   epsilon: 0.1217174136917078
# episode: 165   score: 19.0   memory length: 2000   epsilon: 0.11930605355646196
# episode: 166   score: 13.0   memory length: 2000   epsilon: 0.1176465823493285
# episode: 167   score: 40.0   memory length: 2000   epsilon: 0.11291830038439628
# episode: 168   score: 9.0   memory length: 2000   epsilon: 0.11179418517755796
# episode: 169   score: 10.0   memory length: 2000   epsilon: 0.11057057941158951
# episode: 170   score: 8.0   memory length: 2000   epsilon: 0.10957941546373333
# episode: 171   score: 9.0   memory length: 2000   epsilon: 0.10848853925624609
# episode: 172   score: 11.0   memory length: 2000   epsilon: 0.1071938132148994
# episode: 173   score: 9.0   memory length: 2000   epsilon: 0.1061266859635712
# episode: 174   score: 14.0   memory length: 2000   epsilon: 0.10454588083304645
# episode: 175   score: 11.0   memory length: 2000   epsilon: 0.10329820734275857
# episode: 176   score: 9.0   memory length: 2000   epsilon: 0.10226986131454316
# episode: 177   score: 10.0   memory length: 2000   epsilon: 0.10115050084163021
# episode: 178   score: 11.0   memory length: 2000   epsilon: 0.09994334856146549
# episode: 179   score: 11.0   memory length: 2000   epsilon: 0.09875060270158917
# episode: 180   score: 8.0   memory length: 2000   epsilon: 0.09786539401635165
# episode: 181   score: 9.0   memory length: 2000   epsilon: 0.09689113229559868
# episode: 182   score: 10.0   memory length: 2000   epsilon: 0.09583064289751587
# episode: 183   score: 9.0   memory length: 2000   epsilon: 0.09487663736789426
# episode: 184   score: 9.0   memory length: 2000   epsilon: 0.0939321290776006
# episode: 185   score: 9.0   memory length: 2000   epsilon: 0.09299702348047968
# episode: 186   score: 9.0   memory length: 2000   epsilon: 0.09207122697159466
# episode: 187   score: 9.0   memory length: 2000   epsilon: 0.09115464687785699
# episode: 188   score: 8.0   memory length: 2000   epsilon: 0.09033752897772755
# episode: 189   score: 10.0   memory length: 2000   epsilon: 0.08934876984714372
# episode: 190   score: 10.0   memory length: 2000   epsilon: 0.08837083284806357
# episode: 191   score: 8.0   memory length: 2000   epsilon: 0.08757866929038717
# episode: 192   score: 8.0   memory length: 2000   epsilon: 0.08679360675328379
# episode: 193   score: 7.0   memory length: 2000   epsilon: 0.08610168326587533
# episode: 194   score: 8.0   memory length: 2000   epsilon: 0.08532986055537657
# episode: 195   score: 10.0   memory length: 2000   epsilon: 0.08439591118029047
# episode: 196   score: 8.0   memory length: 2000   epsilon: 0.08363937915383707
# episode: 197   score: 12.0   memory length: 2000   epsilon: 0.08255856723524341
# episode: 198   score: 13.0   memory length: 2000   epsilon: 0.08141023015472601
# episode: 199   score: 8.0   memory length: 2000   epsilon: 0.08068046202340713
# episode: 200   score: 9.0   memory length: 2000   epsilon: 0.07987727835923124
# episode: 201   score: 9.0   memory length: 2000   epsilon: 0.07908209048464582
# episode: 202   score: 9.0   memory length: 2000   epsilon: 0.07829481880060765
# episode: 203   score: 8.0   memory length: 2000   epsilon: 0.0775929774779695
# episode: 204   score: 9.0   memory length: 2000   epsilon: 0.07682053009229402
# episode: 205   score: 8.0   memory length: 2000   epsilon: 0.07613190441729188
# episode: 206   score: 8.0   memory length: 2000   epsilon: 0.07544945164059833
# episode: 207   score: 9.0   memory length: 2000   epsilon: 0.07469834331140734
# episode: 208   score: 7.0   memory length: 2000   epsilon: 0.07410284394064628
# episode: 209   score: 11.0   memory length: 2000   epsilon: 0.07321848433505523
# episode: 210   score: 20.0   memory length: 2000   epsilon: 0.07169617510187196
# episode: 211   score: 9.0   memory length: 2000   epsilon: 0.07098243109022996
# episode: 212   score: 8.0   memory length: 2000   epsilon: 0.07034613862434776
# episode: 213   score: 8.0   memory length: 2000   epsilon: 0.06971554993749822
# episode: 214   score: 9.0   memory length: 2000   epsilon: 0.06902152328662714
# episode: 215   score: 9.0   memory length: 2000   epsilon: 0.06833440575420312
# episode: 216   score: 8.0   memory length: 2000   epsilon: 0.06772185040953389
# episode: 217   score: 8.0   memory length: 2000   epsilon: 0.06711478606235186
# episode: 218   score: 10.0   memory length: 2000   epsilon: 0.06638020367707664
# episode: 219   score: 19.0   memory length: 2000   epsilon: 0.06506513648938707
# episode: 220   score: 8.0   memory length: 2000   epsilon: 0.06448188714861476
# episode: 221   score: 10.0   memory length: 2000   epsilon: 0.06377612227551108
# episode: 222   score: 9.0   memory length: 2000   epsilon: 0.06314122333850061
# episode: 223   score: 9.0   memory length: 2000   epsilon: 0.0625126448964628
# episode: 224   score: 8.0   memory length: 2000   epsilon: 0.06195227630441744
# episode: 225   score: 9.0   memory length: 2000   epsilon: 0.061335533972528195
# episode: 226   score: 9.0   memory length: 2000   epsilon: 0.06072493138443261
# episode: 227   score: 9.0   memory length: 2000   epsilon: 0.06012040741824576
# episode: 228   score: 11.0   memory length: 2000   epsilon: 0.05940291727933882
# episode: 229   score: 9.0   memory length: 2000   epsilon: 0.0588115541219326
# episode: 230   score: 10.0   memory length: 2000   epsilon: 0.05816785197754229
# episode: 231   score: 9.0   memory length: 2000   epsilon: 0.05758878404316422
# episode: 232   score: 8.0   memory length: 2000   epsilon: 0.05707255335279238
# episode: 233   score: 7.0   memory length: 2000   epsilon: 0.05661756776539281
# episode: 234   score: 24.0   memory length: 2000   epsilon: 0.05521898433439589
# episode: 235   score: 9.0   memory length: 2000   epsilon: 0.054669272730650934
# episode: 236   score: 8.0   memory length: 2000   epsilon: 0.054179212784555925
# episode: 237   score: 10.0   memory length: 2000   epsilon: 0.053586212378912985
# episode: 238   score: 8.0   memory length: 2000   epsilon: 0.05310586107665168
# episode: 239   score: 11.0   memory length: 2000   epsilon: 0.05247208407351888
# episode: 240   score: 8.0   memory length: 2000   epsilon: 0.052001719910833674
# episode: 241   score: 9.0   memory length: 2000   epsilon: 0.0514840365598222
# episode: 242   score: 9.0   memory length: 2000   epsilon: 0.05097150680858348
# episode: 243   score: 9.0   memory length: 2000   epsilon: 0.050464079352414384
# episode: 244   score: 11.0   memory length: 2000   epsilon: 0.04986182995226502
# episode: 245   score: 8.0   memory length: 2000   epsilon: 0.04941486432645551
# episode: 246   score: 8.0   memory length: 2000   epsilon: 0.04897190533800461
# episode: 247   score: 8.0   memory length: 2000   epsilon: 0.04853291707107899
# episode: 248   score: 8.0   memory length: 2000   epsilon: 0.048097863931797845
# episode: 249   score: 8.0   memory length: 2000   epsilon: 0.047666710645346916
# episode: 250   score: 8.0   memory length: 2000   epsilon: 0.04723942225311833
# episode: 251   score: 9.0   memory length: 2000   epsilon: 0.04676914814576626
# episode: 252   score: 8.0   memory length: 2000   epsilon: 0.046349905579066174
# episode: 253   score: 9.0   memory length: 2000   epsilon: 0.04588848671675972
# episode: 254   score: 7.0   memory length: 2000   epsilon: 0.04552266113410808
# episode: 255   score: 9.0   memory length: 2000   epsilon: 0.045069477589347
# episode: 256   score: 9.0   memory length: 2000   epsilon: 0.04462080554106098
# episode: 257   score: 9.0   memory length: 2000   epsilon: 0.044176600076762176
# episode: 258   score: 9.0   memory length: 2000   epsilon: 0.04373681673107197
# episode: 259   score: 7.0   memory length: 2000   epsilon: 0.04338814438188925
# episode: 260   score: 11.0   memory length: 2000   epsilon: 0.042870340742886835
# episode: 261   score: 8.0   memory length: 2000   epsilon: 0.04248604741275525
# episode: 262   score: 8.0   memory length: 2000   epsilon: 0.04210519892026722
# episode: 263   score: 8.0   memory length: 2000   epsilon: 0.041727764385609184
# episode: 264   score: 8.0   memory length: 2000   epsilon: 0.04135371320577681
# episode: 265   score: 7.0   memory length: 2000   epsilon: 0.04102403909118487
# episode: 266   score: 8.0   memory length: 2000   epsilon: 0.04065629616391608
# episode: 267   score: 9.0   memory length: 2000   epsilon: 0.04025155786537634
# episode: 268   score: 8.0   memory length: 2000   epsilon: 0.03989073952460687
# episode: 269   score: 8.0   memory length: 2000   epsilon: 0.03953315558970738
# episode: 270   score: 8.0   memory length: 2000   epsilon: 0.03917877706719237
# episode: 271   score: 7.0   memory length: 2000   epsilon: 0.03886644166514151
# episode: 272   score: 11.0   memory length: 2000   epsilon: 0.0384026010189007
# episode: 273   score: 8.0   memory length: 2000   epsilon: 0.03805835688238269
# episode: 274   score: 8.0   memory length: 2000   epsilon: 0.03771719857917758
# episode: 275   score: 9.0   memory length: 2000   epsilon: 0.03734171934916914
# episode: 276   score: 35.0   memory length: 2000   epsilon: 0.036020678301521745
# episode: 277   score: 8.0   memory length: 2000   epsilon: 0.035697785920024
# episode: 278   score: 9.0   memory length: 2000   epsilon: 0.03534241018494339
# episode: 279   score: 8.0   memory length: 2000   epsilon: 0.0350255978557318
# episode: 280   score: 8.0   memory length: 2000   epsilon: 0.03471162545881162
# episode: 281   score: 8.0   memory length: 2000   epsilon: 0.03440046753679158
# episode: 282   score: 9.0   memory length: 2000   epsilon: 0.03405800676162215
# episode: 283   score: 8.0   memory length: 2000   epsilon: 0.03375270793242542
# episode: 284   score: 11.0   memory length: 2000   epsilon: 0.033349895707044996
# episode: 285   score: 9.0   memory length: 2000   epsilon: 0.03301789350028896
# episode: 286   score: 9.0   memory length: 2000   epsilon: 0.032689196415271814
# episode: 287   score: 7.0   memory length: 2000   epsilon: 0.032428596313140684
# episode: 288   score: 8.0   memory length: 2000   epsilon: 0.03213790365586953
# episode: 289   score: 9.0   memory length: 2000   epsilon: 0.03181796697516777
# episode: 290   score: 8.0   memory length: 2000   epsilon: 0.03153274805049819
# episode: 291   score: 9.0   memory length: 2000   epsilon: 0.031218835766339662
# episode: 292   score: 8.0   memory length: 2000   epsilon: 0.03093898750407763
# episode: 293   score: 16.0   memory length: 2000   epsilon: 0.030417211453741086
# episode: 294   score: 8.0   memory length: 2000   epsilon: 0.030144549019052724
# episode: 295   score: 11.0   memory length: 2000   epsilon: 0.029784797354156265
# episode: 296   score: 10.0   memory length: 2000   epsilon: 0.029458797842438697
# episode: 297   score: 8.0   memory length: 2000   epsilon: 0.02919472670774816
# episode: 298   score: 10.0   memory length: 2000   epsilon: 0.02887518561642273
# episode: 299   score: 8.0   memory length: 2000   epsilon: 0.028616346030676164
# episode: 300   score: 8.0   memory length: 2000   epsilon: 0.028359826704686168
# episode: 301   score: 9.0   memory length: 2000   epsilon: 0.028077501232610238
# episode: 302   score: 9.0   memory length: 2000   epsilon: 0.02779798634442866
# episode: 303   score: 8.0   memory length: 2000   epsilon: 0.027548802863305393
# episode: 304   score: 13.0   memory length: 2000   epsilon: 0.02716561656403672
# episode: 305   score: 9.0   memory length: 2000   epsilon: 0.026895179596965687
# episode: 306   score: 7.0   memory length: 2000   epsilon: 0.026680769720969777
# episode: 307   score: 7.0   memory length: 2000   epsilon: 0.026468069132497263
# episode: 308   score: 9.0   memory length: 2000   epsilon: 0.026204576333666588
# episode: 309   score: 8.0   memory length: 2000   epsilon: 0.025969676313525668
# episode: 310   score: 8.0   memory length: 2000   epsilon: 0.025736881956867325
# episode: 311   score: 9.0   memory length: 2000   epsilon: 0.025480668213959144
# episode: 312   score: 7.0   memory length: 2000   epsilon: 0.025277534901822264
# episode: 313   score: 17.0   memory length: 2000   epsilon: 0.02482638618709411
# episode: 314   score: 8.0   memory length: 2000   epsilon: 0.024603840379021556
# episode: 315   score: 9.0   memory length: 2000   epsilon: 0.02435890620074816
# episode: 316   score: 8.0   memory length: 2000   epsilon: 0.024140550922482684
# episode: 317   score: 8.0   memory length: 2000   epsilon: 0.023924152999245944
# episode: 318   score: 8.0   memory length: 2000   epsilon: 0.02370969488514328
# episode: 319   score: 8.0   memory length: 2000   epsilon: 0.02349715919156292
# episode: 320   score: 7.0   memory length: 2000   epsilon: 0.02330983852429035
# episode: 321   score: 15.0   memory length: 2000   epsilon: 0.02293966527733732
# episode: 322   score: 15.0   memory length: 2000   epsilon: 0.022575370588170832
# episode: 323   score: 11.0   memory length: 2000   epsilon: 0.022305951160147018
# episode: 324   score: 9.0   memory length: 2000   epsilon: 0.022083892744312248
# episode: 325   score: 9.0   memory length: 2000   epsilon: 0.021864044946607545
# episode: 326   score: 8.0   memory length: 2000   epsilon: 0.021668053813878495
# episode: 327   score: 8.0   memory length: 2000   epsilon: 0.021473819562101815
# episode: 328   score: 9.0   memory length: 2000   epsilon: 0.021260045116006834
# episode: 329   score: 8.0   memory length: 2000   epsilon: 0.02106946828841925
# episode: 330   score: 8.0   memory length: 2000   epsilon: 0.020880599807498616
# episode: 331   score: 9.0   memory length: 2000   epsilon: 0.020672730935122657
# episode: 332   score: 7.0   memory length: 2000   epsilon: 0.020507926767880855
# episode: 333   score: 9.0   memory length: 2000   epsilon: 0.02030376790025689
# episode: 334   score: 9.0   memory length: 2000   epsilon: 0.020101641458616367
# episode: 335   score: 24.0   memory length: 2000   epsilon: 0.019605084934034504
# episode: 336   score: 8.0   memory length: 2000   epsilon: 0.019429343308326463
# episode: 337   score: 9.0   memory length: 2000   epsilon: 0.019235921868246145
# episode: 338   score: 7.0   memory length: 2000   epsilon: 0.019082572023246296
# episode: 339   score: 19.0   memory length: 2000   epsilon: 0.018704524609493626
# episode: 340   score: 10.0   memory length: 2000   epsilon: 0.018499800507560015
# episode: 341   score: 9.0   memory length: 2000   epsilon: 0.01831563277741149
# episode: 342   score: 9.0   memory length: 2000   epsilon: 0.018133298459078098
# episode: 343   score: 8.0   memory length: 2000   epsilon: 0.017970750050776366
# episode: 344   score: 9.0   memory length: 2000   epsilon: 0.017791849081300208
# episode: 345   score: 8.0   memory length: 2000   epsilon: 0.017632361453859637
# episode: 346   score: 9.0   memory length: 2000   epsilon: 0.017456829183401443
# episode: 347   score: 7.0   memory length: 2000   epsilon: 0.01731766236478993
# episode: 348   score: 9.0   memory length: 2000   epsilon: 0.01714526296146131
# episode: 349   score: 8.0   memory length: 2000   epsilon: 0.01699157138623083
# episode: 350   score: 8.0   memory length: 2000   epsilon: 0.01683925751517146
# episode: 351   score: 8.0   memory length: 2000   epsilon: 0.016688308998427458
# episode: 352   score: 9.0   memory length: 2000   epsilon: 0.016522174883251375
# episode: 353   score: 7.0   memory length: 2000   epsilon: 0.016390459180995933
# episode: 354   score: 9.0   memory length: 2000   epsilon: 0.016227290196431883
# episode: 355   score: 9.0   memory length: 2000   epsilon: 0.016065745578655224
# episode: 356   score: 8.0   memory length: 2000   epsilon: 0.01592173088778779
# episode: 357   score: 8.0   memory length: 2000   epsilon: 0.015779007156688403
# episode: 358   score: 7.0   memory length: 2000   epsilon: 0.01565321602911453
# episode: 359   score: 8.0   memory length: 2000   epsilon: 0.015512899287729736
# episode: 360   score: 9.0   memory length: 2000   epsilon: 0.015358466517026274
# episode: 361   score: 10.0   memory length: 2000   epsilon: 0.01519036557191165
# episode: 362   score: 8.0   memory length: 2000   epsilon: 0.015054197860846403
# episode: 363   score: 9.0   memory length: 2000   epsilon: 0.014904331517795525
# episode: 364   score: 7.0   memory length: 2000   epsilon: 0.014785513353335562
# episode: 365   score: 8.0   memory length: 2000   epsilon: 0.014652974771514253
# episode: 366   score: 9.0   memory length: 2000   epsilon: 0.014507102652380291
# episode: 367   score: 9.0   memory length: 2000   epsilon: 0.014362682707666368
# episode: 368   score: 8.0   memory length: 2000   epsilon: 0.014233934415217388
# episode: 369   score: 7.0   memory length: 2000   epsilon: 0.014120460693954527
# episode: 370   score: 9.0   memory length: 2000   epsilon: 0.01397988981625267
# episode: 371   score: 8.0   memory length: 2000   epsilon: 0.013854572911388743
# episode: 372   score: 10.0   memory length: 2000   epsilon: 0.013702932329434677
# episode: 373   score: 17.0   memory length: 2000   epsilon: 0.013458364956372294
# episode: 374   score: 9.0   memory length: 2000   epsilon: 0.013324385321050682
# episode: 375   score: 9.0   memory length: 2000   epsilon: 0.013191739469048148
# episode: 376   score: 8.0   memory length: 2000   epsilon: 0.013073487610001983
# episode: 377   score: 9.0   memory length: 2000   epsilon: 0.01294333947476804
# episode: 378   score: 7.0   memory length: 2000   epsilon: 0.012840154448553489
# episode: 379   score: 9.0   memory length: 2000   epsilon: 0.012712329172892809
# episode: 380   score: 9.0   memory length: 2000   epsilon: 0.01258577641316355
# episode: 381   score: 10.0   memory length: 2000   epsilon: 0.012448023017815866
# episode: 382   score: 9.0   memory length: 2000   epsilon: 0.012324101457521696
# episode: 383   score: 7.0   memory length: 2000   epsilon: 0.012225853031414649
# episode: 384   score: 10.0   memory length: 2000   epsilon: 0.012092039056748953
# episode: 385   score: 8.0   memory length: 2000   epsilon: 0.01198364500443505
# episode: 386   score: 9.0   memory length: 2000   epsilon: 0.011864346382892048
# episode: 387   score: 9.0   memory length: 2000   epsilon: 0.011746235393417317
# episode: 388   score: 8.0   memory length: 2000   epsilon: 0.011640941154145497
# episode: 389   score: 7.0   memory length: 2000   epsilon: 0.011548138920186161
# episode: 390   score: 8.0   memory length: 2000   epsilon: 0.011444620434315551
# episode: 391   score: 8.0   memory length: 2000   epsilon: 0.011342029896834813
# episode: 392   score: 12.0   memory length: 2000   epsilon: 0.011195464950782337
# episode: 393   score: 9.0   memory length: 2000   epsilon: 0.011084012756089733
# episode: 394   score: 8.0   memory length: 2000   epsilon: 0.010984654736082263
# episode: 395   score: 7.0   memory length: 2000   epsilon: 0.010897084454153863
# episode: 396   score: 9.0   memory length: 2000   epsilon: 0.010788602673048273
# episode: 397   score: 8.0   memory length: 2000   epsilon: 0.01069189273380245
# episode: 398   score: 7.0   memory length: 2000   epsilon: 0.01060665636693042
# episode: 399   score: 9.0   memory length: 2000   epsilon: 0.010501065832223589
# episode: 400   score: 9.0   memory length: 2000   epsilon: 0.010396526463938485
# episode: 401   score: 9.0   memory length: 2000   epsilon: 0.010293027797587458
# episode: 402   score: 8.0   memory length: 2000   epsilon: 0.010200760233091173
# episode: 403   score: 9.0   memory length: 2000   epsilon: 0.010099210443019114
# episode: 404   score: 7.0   memory length: 2000   epsilon: 0.010018698972517958
# episode: 405   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 406   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 407   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 408   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 409   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 410   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 411   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 412   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 413   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 414   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 415   score: 10.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 416   score: 14.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 417   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 418   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 419   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 420   score: 10.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 421   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 422   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 423   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 424   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 425   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 426   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 427   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 428   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 429   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 430   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 431   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 432   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 433   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 434   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 435   score: 10.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 436   score: 10.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 437   score: 18.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 438   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 439   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 440   score: 22.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 441   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 442   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 443   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 444   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 445   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 446   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 447   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 448   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 449   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 450   score: 19.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 451   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 452   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 453   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 454   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 455   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 456   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 457   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 458   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 459   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 460   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 461   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 462   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 463   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 464   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 465   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 466   score: 11.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 467   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 468   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 469   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 470   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 471   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 472   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 473   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 474   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 475   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 476   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 477   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 478   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 479   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 480   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 481   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 482   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 483   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 484   score: 10.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 485   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 486   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 487   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 488   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 489   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 490   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 491   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 492   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 493   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 494   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 495   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 496   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 497   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 498   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 499   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 500   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 501   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 502   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 503   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 504   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 505   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 506   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 507   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 508   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 509   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 510   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 511   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 512   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 513   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 514   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 515   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 516   score: 7.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 517   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 518   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 519   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 520   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 521   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 522   score: 8.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 523   score: 10.0   memory length: 2000   epsilon: 0.009998671593271896
